# %% [markdown]
# <a href="https://colab.research.google.com/github/SofyaZeleneva/MMVSULAB1/blob/main/%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colaboratory!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная 2(Челябинск)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.integrate import odeint

data ={'года' : [1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],
'Population' : [3067589,3040417,3011011,2994506,3001903,2994236,2987749,2989882,2991888,2982971,2972886,2959711,2943758,2924376,2907242,2872719,2861275,2855471,2852859,2850655,2849601,2857147,2865583,2875003,2886692,2891138,2893639,2888662,2874978]}

df = pd.DataFrame(data)
df.head()
plt.plot(df['года'],df['Population'])
plt.xlabel('года')
plt.ylabel('Population')
plt.title('Population of Chelyabinsk',fontsize=13)
plt.show()

# %% [markdown]
# Задание 2

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  #return x*k(x)
#ef k(x):
  a=0.000012
  b=-0.005
  return (a*x-b)/2

t=np.linspace(0,29,29)

solve = odeint(dydt, 3000000, t=t)
solve = solve.flatten()
d = [1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
k = [3067589,3040417,3011011,2994506,3001903,2994236,2987749,2989882,2991888,2982971,2972886,2959711,2943758,2924376,2907242,2872719,2861275,2855471,2852859,2850655,2849601,2857147,2865583,2875003,2886692,2891138,2893639,2888662,2874978]

# %matplotlib inline

plt.plot(d,solve,label=r"x'=kx")
plt.plot(d, k)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **С подбором коэффициента **

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k=-0.002569
  return k*x
t=np.linspace(0,29,29)

solve = odeint(dydt, 3067589, t=t)
solve = solve.flatten()
d = [1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
k = [3067589,3040417,3011011,2994506,3001903,2994236,2987749,2989882,2991888,2982971,2972886,2959711,2943758,2924376,2907242,2872719,2861275,2855471,2852859,2850655,2849601,2857147,2865583,2875003,2886692,2891138,2893639,2888662,2874978]

# %matplotlib inline

plt.plot(d,solve,label=r"x'=kx")
plt.plot(d, k)
plt.grid(True)
plt.legend()
plt.show()
